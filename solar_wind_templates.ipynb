# %% [markdown]
# # Templates — Solar (classificação) e Wind (regressão)
# Este notebook contém templates e instruções para os exercícios sugeridos no enunciado:
# - **Solar:** classificação de níveis de radiação (Alta vs Baixa).
# - **Wind:** regressão para prever potência gerada por turbinas eólicas.

# %% [markdown]
# ## Instruções gerais
# 1. Obtenha os datasets sugeridos (Kaggle) e coloque-os em `../data/`.
# 2. Ajuste os nomes de colunas e as seleções de features conforme o CSV real.
# 3. Separe treino/teste (70/30 ou 80/20 conforme solicitado).

# %%
# Imports comuns
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, r2_score, mean_squared_error

print('Coloque os CSVs em ../data/ e atualize os nomes de arquivo abaixo para carregar.')

# Exemplo de carregamento (editar conforme o dataset exato)
solar_csv = '../data/solar_radiation.csv'  # atualizar
wind_csv = '../data/wind_turbine_scada.csv'  # atualizar

# --- Solar (clasificação) ---
try:
    df_solar = pd.read_csv(solar_csv)
    display(df_solar.head())
except Exception as e:
    print('Não foi possível carregar o CSV solar:', e)

# --- Wind (regressão) ---
try:
    df_wind = pd.read_csv(wind_csv)
    display(df_wind.head())
except Exception as e:
    print('Não foi possível carregar o CSV wind:', e)

# %% [markdown]
# ## Métricas sugeridas
# - **Classificação:** acurácia, matriz de confusão, F1-score.
# - **Regressão:** R², RMSE.
